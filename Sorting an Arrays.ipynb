# %%
# %matplotlib notebook
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# %%
x = np.random.randint(0,100, size = 20)
y = np.random.randint(0,400, size = 30)

# %%
np.sort(x)
# Out:
# array([14, 14, 21, 28, 30, 37, 40, 44, 46, 53, 58, 69, 75, 75, 77, 85, 86,
#        88, 91, 93])

# %%
np.argsort(x)
# Out:
# array([ 8, 10,  3, 12, 17,  0, 15,  4,  7,  1, 16, 13, 19,  6,  9, 18,  5,
#         2, 11, 14])

# %%
x.sort()
x
# Out:
# array([14, 14, 21, 28, 30, 37, 40, 44, 46, 53, 58, 69, 75, 75, 77, 85, 86,
#        88, 91, 93])

# %%
x = np.random.randint(0,100, size = (7,8))
x
# Out:
# array([[89,  1, 23, 53, 50, 43, 90, 69],
#        [73, 27, 91, 38, 65, 47, 92, 12],
#        [ 4, 69, 83,  0, 60, 36, 69, 62],
#        [67, 98,  5, 68, 51, 64,  4, 82],
#        [59, 49, 41, 15,  8,  1, 38, 31],
#        [88, 80, 14, 45, 71, 77,  2, 38],
#        [ 4, 44, 78, 83,  3, 57, 46, 60]])

# %%
np.sort(x, axis = 0)
# Out:
# array([[ 4,  1,  5,  0,  3,  1,  2, 12],
#        [ 4, 27, 14, 15,  8, 36,  4, 31],
#        [59, 44, 23, 38, 50, 43, 38, 38],
#        [67, 49, 41, 45, 51, 47, 46, 60],
#        [73, 69, 78, 53, 60, 57, 69, 62],
#        [88, 80, 83, 68, 65, 64, 90, 69],
#        [89, 98, 91, 83, 71, 77, 92, 82]])

# %%
np.sort(x, axis = 1)
# Out:
# array([[ 1, 23, 43, 50, 53, 69, 89, 90],
#        [12, 27, 38, 47, 65, 73, 91, 92],
#        [ 0,  4, 36, 60, 62, 69, 69, 83],
#        [ 4,  5, 51, 64, 67, 68, 82, 98],
#        [ 1,  8, 15, 31, 38, 41, 49, 59],
#        [ 2, 14, 38, 45, 71, 77, 80, 88],
#        [ 3,  4, 44, 46, 57, 60, 78, 83]])

# %%
np.sort(x, axis = 0)
# Out:
# array([[ 4,  1,  5,  0,  3,  1,  2, 12],
#        [ 4, 27, 14, 15,  8, 36,  4, 31],
#        [59, 44, 23, 38, 50, 43, 38, 38],
#        [67, 49, 41, 45, 51, 47, 46, 60],
#        [73, 69, 78, 53, 60, 57, 69, 62],
#        [88, 80, 83, 68, 65, 64, 90, 69],
#        [89, 98, 91, 83, 71, 77, 92, 82]])

# %%
np.sort(x, axis = 1)
# Out:
# array([[ 1, 23, 43, 50, 53, 69, 89, 90],
#        [12, 27, 38, 47, 65, 73, 91, 92],
#        [ 0,  4, 36, 60, 62, 69, 69, 83],
#        [ 4,  5, 51, 64, 67, 68, 82, 98],
#        [ 1,  8, 15, 31, 38, 41, 49, 59],
#        [ 2, 14, 38, 45, 71, 77, 80, 88],
#        [ 3,  4, 44, 46, 57, 60, 78, 83]])

# %%
x = np.array([7, 2, 3, 1, 6, 5, 4])
np.partition(x, 3)
# Out:
# array([2, 1, 3, 4, 6, 5, 7])

# %%
x = np.random.randint(0,100, size = (7,8))
x
# Out:
# array([[16, 64, 50, 84, 50, 62, 65, 19],
#        [25, 60, 92, 98, 13, 24, 70, 99],
#        [35, 51,  1, 11, 30,  0, 12, 95],
#        [99,  2, 78, 25, 82, 34, 77, 84],
#        [ 7, 97, 75, 85, 77, 83, 94, 32],
#        [89, 65, 24, 97, 93, 47, 72, 66],
#        [91, 79, 95,  6, 41, 32, 46, 62]])

# %%
np.partition(x, 4, axis =1)
# Out:
# array([[16, 19, 50, 50, 62, 64, 65, 84],
#        [13, 24, 25, 60, 70, 92, 98, 99],
#        [ 0,  1, 11, 12, 30, 35, 51, 95],
#        [ 2, 34, 25, 77, 78, 82, 84, 99],
#        [ 7, 32, 75, 77, 83, 85, 94, 97],
#        [24, 47, 65, 66, 72, 89, 93, 97],
#        [41,  6, 46, 32, 62, 79, 95, 91]])

# %%
np.partition(x, 3, axis = 0)
# Out:
# array([[25, 60,  1, 11, 13, 24, 12, 32],
#        [ 7,  2, 24,  6, 41, 32, 46, 19],
#        [16, 51, 50, 25, 30,  0, 65, 62],
#        [35, 64, 75, 84, 50, 34, 70, 66],
#        [89, 97, 78, 85, 77, 83, 72, 84],
#        [91, 65, 92, 97, 93, 47, 77, 95],
#        [99, 79, 95, 98, 82, 62, 94, 99]])

# %%
np.argpartition(x, 3, axis =0)
# Out:
# array([[1, 1, 2, 2, 1, 1, 2, 4],
#        [4, 3, 5, 6, 6, 6, 6, 0],
#        [0, 2, 0, 3, 2, 2, 0, 6],
#        [2, 0, 4, 0, 0, 3, 1, 5],
#        [5, 4, 3, 4, 4, 4, 5, 3],
#        [6, 5, 1, 5, 5, 5, 3, 2],
#        [3, 6, 6, 1, 3, 0, 4, 1]])

# %%
X = np.random.rand(10,2)
X.shape
# Out:
# (10, 2)

# %%
plt.scatter(X[:,0], X[:,1], s= 50)
# Out:
# <img src="data:image/png;base64,..." width="640">
